# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Read data from cleaned file

df = pd.read_csv('../data/clean_Diabetes.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 532 entries, 0 to 531
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                532 non-null    int64
#  1   Pregnancies               532 non-null    int64
#  2   Glucose                   532 non-null    int64
#  3   BloodPressure             532 non-null    int64
#  4   SkinThickness             532 non-null    int64
#  5   Insulin                   532 non-null    int64
#  6   BMI                       532 non-null    float64
#  7   DiabetesPedigreeFunction  532 non-null    float64
#  8   Age                       532 non-null    int64
#  9   Outcome                   532 non-null    int64
# dtypes: float64(2), int64(8)
# memory usage: 41.7 KB

# %%
df.head()
# Out:
#    Unnamed: 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0           0            6      148             72             35        0
# 1           1            1       85             66             29        0
# 2           3            1       89             66             23       94
# 3           4            0      137             40             35      168
# 4           6            3       78             50             32       88
#
#     BMI  DiabetesPedigreeFunction  Age  Outcome
# 0  33.6                     0.627   50        1
# 1  26.6                     0.351   31        0
# 2  28.1                     0.167   21        0
# 3  43.1                     2.288   33        1
# 4  31.0                     0.248   26        1

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Pregnancies', 'Glucose', 'BloodPressure',
#        'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age',
#        'Outcome'],
#       dtype='object')

# %%
df.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
sns.pairplot(df)

# %%
# Correlation matrix

plt.subplots(figsize = (12, 8))
sns.heatmap(df.corr(), annot = True, cmap = 'coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Outcome (target variable) has moderate positive correlated with glucose and has low positive correlation
# ### with Age, BMI, Pregnanacies, SkinThickness, DiabetesPedigreeFunction, Insulin and BloodPressure.

# %% [markdown]
# ### There are moderate positive correlations between the pairs --
# ### Age and Pregnancies, and
# ### BMI and SkinThickness.

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   532.000000  532.000000     532.000000     532.000000  532.000000
# mean      3.516917  121.030075      71.505639      29.182331  114.988722
# std       3.312036   30.999226      12.310253      10.523878  123.007555
# min       0.000000   56.000000      24.000000       7.000000    0.000000
# 25%       1.000000   98.750000      64.000000      22.000000    0.000000
# 50%       2.000000  115.000000      72.000000      29.000000   91.500000
# 75%       5.000000  141.250000      80.000000      36.000000  165.250000
# max      17.000000  199.000000     110.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  532.000000                532.000000  532.000000  532.000000
# mean    32.890226                  0.502966   31.614662    0.332707
# std      6.881109                  0.344546   10.761584    0.471626
# ...

# %%
# Get the distribution plots of all variables
plt.subplots(figsize = (12, 8))
sns.histplot(df)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
# Examine how Outcome is by the independent variables

# %%
sns.jointplot(x = 'Glucose', y = 'Outcome', data = df)

# %%
sns.distplot(df['Glucose'])
# Out:
# <AxesSubplot:xlabel='Glucose', ylabel='Density'>

# %%
### Observation: This is in keeping with norms that people with Glucose higher than 100 are at risk of diabetes.
